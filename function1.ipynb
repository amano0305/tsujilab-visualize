# %%
# グラフを書いてみよう
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 4, 5)
y = x

plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = x+2

plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = x

plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = x

plt.plot(x, y, marker='o')

x = np.linspace(0, 4 ,5)
y= x+2

plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = x

plt.plot(x, y, marker='o')

x = np.linspace(0, 4 ,5)
y= x+2

plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = x

plt.xlim([0,6])
plt.ylim([0,6])

plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = x

plt.xlim([0,6])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = 2*x

plt.xlim([0,6])
plt.ylim([0,12])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(0, 4, 5)
y = 3*x

plt.xlim([0,6])
plt.ylim([0,18])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(-6, 6, 13)
y = -x

plt.xlim([-6,6])
plt.ylim([-6,6])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(-6, 6, 13)
y = -x+3

plt.xlim([-6,6])
plt.ylim([-6,6])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(-4, 4, 11)
y = -x**2 +10

plt.xlim([-5,5])
plt.ylim([-18,18])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(-2, 6, 11)
y = -(x-2)**2 +10

plt.xlim([-5,8])
plt.ylim([-18,18])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(-6, 6, 31)
y = np.sin(x)

plt.xlim([-6,6])
plt.ylim([-2,2])
plt.plot(x, y, marker='o')

# %%
x = np.linspace(-6, 6, 31)
y = np.sin(x)

plt.xlim([-6,6])
plt.ylim([-2,2])
plt.plot(x, y, marker='o')

x=np.linspace(-6,6, 31)
y=x*0
plt.plot(x,y,)

# %%
x = np.linspace(-6, 6, 31)
y = np.cos(x)

plt.xlim([-6,6])
plt.ylim([-2,2])
plt.plot(x, y, marker='o')

x=np.linspace(-6,6, 31)
y=x*0
plt.plot(x,y,)
